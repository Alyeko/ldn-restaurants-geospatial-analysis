# %% [markdown]
# ### Importing needed packages

# %%
import os
import fiona
import folium
import requests
import matplotlib
#import osmnx as ox
import pandas as pd
import geopandas as gpd
import plotly.express as px
from pyproj import Transformer
from folium.plugins import Draw
import matplotlib.pyplot as plt
from scipy.spatial import ConvexHull
from folium.plugins import BeautifyIcon
from sklearn.cluster import MiniBatchKMeans
from matplotlib_scalebar.scalebar import ScaleBar
from matplotlib.font_manager import FontProperties
from shapely.geometry import Point, LineString, Polygon

# %% [markdown]
# ### Reading the dataframe of restaurant data

# %%
df = pd.read_csv('data/rdata.csv')
df.head()
# Out:
#                         _id          BusinessName         RatingValue  \
# 0  620cd586aa28c13b79512f6f      101 Thai Kitchen                   3
# 1  620cd586aa28c13b79512f75    2020 Mezza & Grill  AwaitingInspection
# 2  620cd586aa28c13b79512f78  222 Vegan Restaurant                   3
# 3  620cd586aa28c13b79512f7b    24 / 7 Supermarket                   3
# 4  620cd586aa28c13b79512f7e            696 Mangal                   5
#
#   AddressLine2 PostCode  Geocode_Longitude  Geocode_Latitude
# 0       London   W6 0RX          -0.244311         51.493618
# 1       London   W6 9PL          -0.222939         51.488278
# 2       London  W14 9NU          -0.202997         51.485879
# 3       London   W6 0QU          -0.232831         51.492834
# 4       London  SW6 5SA          -0.206834         51.474724

# %%
gpd.__version__
# Out:
# '0.10.2'

# %%
gdf = gpd.GeoDataFrame(df, geometry= gpd.points_from_xy(df.Geocode_Longitude, df.Geocode_Latitude))
gdf.head()
# Out:
#                         _id          BusinessName         RatingValue  \
# 0  620cd586aa28c13b79512f6f      101 Thai Kitchen                   3
# 1  620cd586aa28c13b79512f75    2020 Mezza & Grill  AwaitingInspection
# 2  620cd586aa28c13b79512f78  222 Vegan Restaurant                   3
# 3  620cd586aa28c13b79512f7b    24 / 7 Supermarket                   3
# 4  620cd586aa28c13b79512f7e            696 Mangal                   5
#
#   AddressLine2 PostCode  Geocode_Longitude  Geocode_Latitude  \
# 0       London   W6 0RX          -0.244311         51.493618
# 1       London   W6 9PL          -0.222939         51.488278
# 2       London  W14 9NU          -0.202997         51.485879
# 3       London   W6 0QU          -0.232831         51.492834
# 4       London  SW6 5SA          -0.206834         51.474724
#
#                     geometry
# 0  POINT (-0.24431 51.49362)
# 1  POINT (-0.22294 51.48828)
# 2  POINT (-0.20300 51.48588)
# 3  POINT (-0.23283 51.49283)
# 4  POINT (-0.20683 51.47472)

# %%
gdf.crs = "EPSG:4326" #Adding crs information to geodataframe
gdf.plot(marker = '*', color = 'green') #Plotting the geodataframe
plt.rcParams['figure.figsize'] = [10, 10]

# %%
#Loading United Kingdom Data from gpd datasets
# load a sample geodataframe
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))  
uk = world[world['name'] == 'United Kingdom']

ax = uk.plot(color ='#e3bccf', edgecolor = 'blue')
plt.rcParams['figure.figsize'] = [10, 10] 

# for x, y, label in zip(uk.geometry.representative_point().x, uk.geometry.representative_point().y, africa_gdf.name):
#     ax.annotate(label, xy=(x, y))
    
gdf.plot(ax=ax, color = 'green')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### From the plot above it can be seen that not all the points are in London, and will be removed...
# #### To do this, we need another dataset that has the London spatial data information, ie London shapefile...

# %%
london = gpd.read_file("data/greater_london_const_region.shp")
london.crs #crs here is projected whereas points geodataframe ('gdf') is geographic crs as seen in the next cell
# Out:
# <Projected CRS: EPSG:27700>
# Name: OSGB 1936 / British National Grid
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: UK - Britain and UKCS 49°46'N to 61°01'N, 7°33'W to 3°33'E
# - bounds: (-9.2, 49.75, 2.88, 61.14)
# Coordinate Operation:
# - name: British National Grid
# - method: Transverse Mercator
# Datum: OSGB 1936
# - Ellipsoid: Airy 1830
# - Prime Meridian: Greenwich

# %%
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
london['geometry'].to_crs(epsg=4326)#, allow_override=True)
london_new = london.to_crs(epsg=4326)#, allow_override=True)
london_new.head()
# Out:
#                                        NAME AREA_CODE  \
# 0  Havering and Redbridge GL Assembly Const       LAC
# 1      Croydon and Sutton GL Assembly Const       LAC
# 2      Bexley and Bromley GL Assembly Const       LAC
# 3              South West GL Assembly Const       LAC
# 4   Ealing and Hillingdon GL Assembly Const       LAC
#
#                                        DESCRIPTIO                 FILE_NAME  \
# 0  Greater London Authority Assembly Constituency  GREATER_LONDON_AUTHORITY
# 1  Greater London Authority Assembly Constituency  GREATER_LONDON_AUTHORITY
# 2  Greater London Authority Assembly Constituency  GREATER_LONDON_AUTHORITY
# 3  Greater London Authority Assembly Constituency  GREATER_LONDON_AUTHORITY
# 4  Greater London Authority Assembly Constituency  GREATER_LONDON_AUTHORITY
#
#    NUMBER  NUMBER0  POLYGON_ID  UNIT_ID       CODE   HECTARES     AREA  \
# 0       1        1      112074    41452  E32000009  17089.120  215.025
# 1       2        2      112056    41443  E32000005  13032.722    0.000
# 2       3        3      112066    41448  E32000002  21444.201  373.731
# 3       4        4      112076    41453  E32000013  15259.582  198.064
# 4       5        5      112054    41442  E32000006  17124.805    0.000
#
#   TYPE_CODE          DESCRIPT0 TYPE_COD0 DESCRIPT1  \
# 0        VA  CIVIL VOTING AREA      None      None
# 1        VA  CIVIL VOTING AREA      None      None
# 2        VA  CIVIL VOTING AREA      None      None
# 3        VA  CIVIL VOTING AREA      None      None
# 4        VA  CIVIL VOTING AREA      None      None
#
#                                             geometry
# 0  POLYGON ((0.18854 51.48443, 0.18840 51.48445, ...
# 1  POLYGON ((-0.11139 51.42317, -0.11096 51.42315...
# 2  POLYGON ((0.15925 51.50871, 0.15994 51.50869, ...
# 3  POLYGON ((-0.28031 51.50245, -0.28021 51.50237...
# 4  POLYGON ((-0.49463 51.63104, -0.49457 51.63104...

# %% [markdown]
# Breakdown of spatial datasets we have so far...
# 1. gdf
# 2. london
# 3. london_new

# %%
london_new.crs #projected coordinate system
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# ax = london.plot()
# gdf.plot(ax=ax)

ax = gdf.plot(alpha=0.1, color='green')
london_new.plot(ax=ax, color = '#C6A619')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Plot is not very intuitive, london boundary is shown by a small yellow dot!

# %%
london_new.plot(color='#C6A619')
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the london plot above, it is seen that the highest latitude value is about 51.7 and the lowest value about 51.2
# the lowest longitude value is about -0.2 and the highest value about 0.4

# %%
to_del = []
long_del_east = gdf[gdf['Geocode_Longitude'] > 0.4].index.to_list()
long_del_west = gdf[gdf['Geocode_Longitude'] <-0.5].index.to_list()
lat_del_upper = gdf[gdf['Geocode_Latitude'] >51.7].index.to_list()
lat_del_lower = gdf[gdf['Geocode_Latitude'] <51.2].index.to_list()

to_del.extend(long_del_east)
to_del.extend(long_del_west)
to_del.extend(lat_del_upper)
to_del.extend(lat_del_lower)
print(len(to_del))
to_del = set(to_del)
print(len(to_del))
# Out:
# 62
# 33

# %%
print(f'Before deletion of rows: {len(gdf)}')
gdf = gdf.drop(index=to_del)
print(f'After deletion of rows: {len(gdf)}')
# Out:
# Before deletion of rows: 22288
# After deletion of rows: 22255

# %%
gdf.plot() #looks much better, and within the london area range
# Out:
# <AxesSubplot:>

# %%
ax = london_new.plot(edgecolor='blue',color='#F1C40F')
gdf.plot(ax=ax, marker='*')
plt.rcParams['figure.figsize']= [8, 8]  #Some points are shown outside the boundary of london but can be ignored for now

# %% [markdown]
# ### Cluster Analysis

# %% [markdown]
# #### Code for cluster analysis adapted from https://towardsdatascience.com/finding-and-visualizing-clusters-of-geospatial-data-698943c18fed

# %% [markdown]
# MiniBatchKMeans?

# %%
ssd = []
for i in range(2, 26):
    km = MiniBatchKMeans(n_clusters=i)
    km.fit_predict(gdf[['Geocode_Longitude','Geocode_Latitude']])
    ssd.append(km.inertia_)

# %%
k = range(2, 26)
plt.plot(k, ssd, marker='x', color='purple')
plt.xlabel('k values')
plt.ylabel('Inertia vaules')
plt.title('Elbow method to find the optimal k value')
# Out:
# Text(0.5, 1.0, 'Elbow method to find the optimal k value')

# %% [markdown]
# #### From the plot above we can conclude that the optimal k value is 15 since that is when the inertia values start decreasing linearly

# %%
cluster = MiniBatchKMeans(n_clusters=12, random_state=1, verbose=1, )
cluster.fit_predict(gdf[['Geocode_Longitude','Geocode_Latitude']])
# Out:
# Init 1/3 with method k-means++
# Inertia for init 1/3: 2.9171357538432776
# Init 2/3 with method k-means++
# Inertia for init 2/3: 2.4381737998787374
# Init 3/3 with method k-means++
# Inertia for init 3/3: 2.8549039174296835
# Minibatch step 1/2173: mean batch inertia: 0.0008130470885070919
# Minibatch step 2/2173: mean batch inertia: 0.0006953757199428466, ewa inertia: 0.0006953757199428466
# Minibatch step 3/2173: mean batch inertia: 0.0006679548619166957, ewa inertia: 0.0006928524490389305
# Minibatch step 4/2173: mean batch inertia: 0.0006830595568290257, ewa inertia: 0.0006919513058305424
# Minibatch step 5/2173: mean batch inertia: 0.0006703868334736166, ewa inertia: 0.0006899669402937441
# Minibatch step 6/2173: mean batch inertia: 0.0006730120221644486, ewa inertia: 0.0006884067465334639
# Minibatch step 7/2173: mean batch inertia: 0.0006659587292914318, ewa inertia: 0.0006863410770820044
# Minibatch step 8/2173: mean batch inertia: 0.000708890354000444, ewa inertia: 0.0006884160644619903
# Minibatch step 9/2173: mean batch inertia: 0.0006958068328972839, ewa inertia: 0.0006890961639297959
# Minibatch step 10/2173: mean batch inertia: 0.0006470810775186394, ewa inertia: 0.0006852299302413502
# Minibatch step 11/2173: mean batch inertia: 0.0006093082478286587, ewa inertia: 0.0006782436072012175
# Minibatch step 12/2173: mean batch inertia: 0.0006294979140419014, ewa inertia: 0.0006737580222088434
# Minibatch step 13/2173: mean batch inertia: 0.0006645352938857809, ewa inertia: 0.0006729093455551036
# Minibatch step 14/2173: mean batch inertia: 0.0006614475203826006, ewa inertia: 0.0006718546269195319
# Minibatch step 15/2173: mean batch inertia: 0.000635839379349464, ewa inertia: 0.0006685404991776421
# Minibatch step 16/2173: mean batch inertia: 0.0006148818026074717, ewa inertia: 0.0006636028189756422
# Minibatch step 17/2173: mean batch inertia: 0.0005981868793305551, ewa inertia: 0.0006575832357444624
# Minibatch step 18/2173: mean batch inertia: 0.0006079494331719104, ewa inertia: 0.000653015926808958
# Minibatch step 19/2173: mean batch inertia: 0.000652016437098967, ewa inertia: 0.0006529239536365073
# Minibatch step 20/2173: mean batch inertia: 0.0005955415212804273, ewa inertia: 0.0006476436147856244
# Minibatch step 21/2173: mean batch inertia: 0.0006294726983691889, ewa inertia: 0.0006459715247056074
# Minibatch step 22/2173: mean batch inertia: 0.0006119811097591009, ewa inertia: 0.0006428437223237577
# Minibatch step 23/2173: mean batch inertia: 0.0006207119156304945, ewa inertia: 0.0006408071506079147
# Minibatch step 24/2173: mean batch inertia: 0.0006098003842880531, ewa inertia: 0.000637953903958783
# Minibatch step 25/2173: mean batch inertia: 0.0006457673511993075, ewa inertia: 0.000638672898384942
# Minibatch step 26/2173: mean batch inertia: 0.00063320594719949, ewa inertia: 0.0006381698288294152
# Minibatch step 27/2173: mean batch inertia: 0.0006412499174198297, ewa inertia: 0.0006384532589800788
# Minibatch step 28/2173: mean batch inertia: 0.0006468229094844164, ewa inertia: 0.0006392234353025484
# Minibatch step 29/2173: mean batch inertia: 0.0006345497380567785, ewa inertia: 0.0006387933610772008
# Minibatch step 30/2173: mean batch inertia: 0.0005852053525492267, ewa inertia: 0.0006338621855979912
# Minibatch step 31/2173: mean batch inertia: 0.0006141598544508624, ewa inertia: 0.0006320491745362857
# Minibatch step 32/2173: mean batch inertia: 0.0005973805803413143, ewa inertia: 0.0006288589660122337
# Minibatch step 33/2173: mean batch inertia: 0.0006249536328685238, ewa inertia: 0.0006284995967509865
# Minibatch step 34/2173: mean batch inertia: 0.0006641853061343556, ewa inertia: 0.000631783400346293
# Minibatch step 35/2173: mean batch inertia: 0.0006577548797968276, ewa inertia: 0.0006341732992461265
# Minibatch step 36/2173: mean batch inertia: 0.0006443460135700022, ewa inertia: 0.0006351093937345925
# Minibatch step 37/2173: mean batch inertia: 0.0006812154748598595, ewa inertia: 0.000639352081286019
# Minibatch step 38/2173: mean batch inertia: 0.0006031162180092988, ewa inertia: 0.0006360176524582546
# Minibatch step 39/2173: mean batch inertia: 0.0005914516158383964, ewa inertia: 0.0006319166800015028
# Minibatch step 40/2173: mean batch inertia: 0.0006012608715521615, ewa inertia: 0.0006290957285410314
# Minibatch step 41/2173: mean batch inertia: 0.0006127779694993492, ewa inertia: 0.0006275941662424438
# Minibatch step 42/2173: mean batch inertia: 0.0006434973874846042, ewa inertia: 0.0006290575827190769
# Minibatch step 43/2173: mean batch inertia: 0.0006728147380596117, ewa inertia: 0.0006330841218158336
# Minibatch step 44/2173: mean batch inertia: 0.0005903726625732155, ewa inertia: 0.0006291538078093238
# Minibatch step 45/2173: mean batch inertia: 0.0006375291137403428, ewa inertia: 0.0006299245045448885
# Minibatch step 46/2173: mean batch inertia: 0.0006239268669855631, ewa inertia: 0.0006293726011605653
# Minibatch step 47/2173: mean batch inertia: 0.0006165171583996334, ewa inertia: 0.0006281896416541675
# Minibatch step 48/2173: mean batch inertia: 0.0006317694898379876, ewa inertia: 0.0006285190597472869
# Minibatch step 49/2173: mean batch inertia: 0.0005594775188028, ewa inertia: 0.0006221658482153716
# Minibatch step 50/2173: mean batch inertia: 0.0006163554410919516, ewa inertia: 0.0006216311737999886
# Minibatch step 51/2173: mean batch inertia: 0.000688310490667476, ewa inertia: 0.000627767013166659
# Minibatch step 52/2173: mean batch inertia: 0.0006267873254749666, ewa inertia: 0.0006276768621784947
# Minibatch step 53/2173: mean batch inertia: 0.0006929561558432372, ewa inertia: 0.0006336838712288807
# Minibatch step 54/2173: mean batch inertia: 0.000627519315301341, ewa inertia: 0.0006331166079947147
# Minibatch step 55/2173: mean batch inertia: 0.0006054712937048621, ewa inertia: 0.0006305726825963673
# Minibatch step 56/2173: mean batch inertia: 0.0006446160227060333, ewa inertia: 0.0006318649525705133
# Minibatch step 57/2173: mean batch inertia: 0.0006258288895673979, ewa inertia: 0.0006313095132718801
# Minibatch step 58/2173: mean batch inertia: 0.0006490769400668282, ewa inertia: 0.000632944474184715
# Minibatch step 59/2173: mean batch inertia: 0.0006284894340467483, ewa inertia: 0.0006325345208147223
# Minibatch step 60/2173: mean batch inertia: 0.0006003953768521199, ewa inertia: 0.0006295770726283722
# Converged (lack of improvement in inertia) at step 60/2173
# array([ 2, 11, 11, ...,  1, 11,  1])

# %%
cluster.inertia_
# Out:
# 13.909907596975831

# %%
centers = cluster.cluster_centers_
centers

n_clusters = len(cluster.cluster_centers_)
n_clusters
# Out:
# 12

# %%
centers_gs = gpd.GeoSeries(map(Point, zip(centers[:,0], centers[:,1])), crs= 'epsg:4326')
centers_gs #coordinates of cluster points
# Out:
# 0     POINT (-0.06663 51.60498)
# 1     POINT (-0.13565 51.50362)
# 2     POINT (-0.24490 51.53672)
# 3     POINT (-0.02023 51.51802)
# 4     POINT (-0.11334 51.43799)
# 5     POINT (-0.18643 51.44572)
# 6     POINT (-0.07774 51.51859)
# 7      POINT (0.04105 51.53412)
# 8     POINT (-0.11465 51.60825)
# 9     POINT (-0.31079 51.51028)
# 10    POINT (-0.02470 51.45129)
# 11    POINT (-0.19263 51.50661)
# dtype: geometry

# %%
centers_gs.plot(marker='X', color='black', markersize=100) #These are what center points of clusters look like
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Center points of clusters only')
# Out:
# Text(0.5, 1.0, 'Center points of clusters only')

# %%
##### clusters are plotted with this function as well(code adapted from https://stackoverflow.com/questions/28227340/kmeans-scatter-plot-plot-different-colors-per-cluster)
plt.scatter(gdf.Geocode_Longitude, gdf.Geocode_Latitude, c=[matplotlib.cm.Spectral(float(i) /10) for i in cluster.labels_]);

# %%
#Plotting London shapefile
fig, ax = plt.subplots(figsize=(10, 10))
ax.set_aspect('equal')
london_new.plot(ax=ax, alpha=0.4, edgecolor='darkgrey', color='lightgrey', zorder=1)

centers_gs.plot(ax=ax, color='black', marker='X', alpha=1, markersize=100, zorder=3)
gdf.plot(ax=ax, 
         alpha=0.5, 
         c=[matplotlib.cm.Spectral(float(i) /10) for i in cluster.labels_], 
         linewidth=0.8, zorder=2)
plt.xlabel('Longitude')
plt.ylabel('Latitude')

#Adding cluster center label to legend
legend_drawn_flag = True
plt.legend(['Cluster centers'], frameon=legend_drawn_flag)

#Adding north arrow
x, y, arrow_length = 0.035, 0.96, 0.12
ax.annotate('N', xy=(x, y), xytext=(x, y-arrow_length),
            arrowprops=dict(facecolor='black', width=15, headwidth=35),
            ha='center', va='center', fontsize=20,
            xycoords=ax.transAxes) 


#Adding scalebar
scalebar = ScaleBar(2, "cm", length_fraction=0.25, location='lower center')
ax.add_artist(scalebar)   

plt.title('London Map showing restaurants grouped into 10 clusters')
plt.savefig('imgs/screenshot2.PNG', dpi=300, bbox_inches="tight")

# %%
gdf.geometry
# Out:
# 0        POINT (-0.24431 51.49362)
# 1        POINT (-0.22294 51.48828)
# 2        POINT (-0.20300 51.48588)
# 3        POINT (-0.23283 51.49283)
# 4        POINT (-0.20683 51.47472)
#                    ...
# 22283    POINT (-0.13931 51.50801)
# 22284    POINT (-0.14351 51.49742)
# 22285    POINT (-0.14351 51.49742)
# 22286    POINT (-0.16445 51.49950)
# 22287    POINT (-0.14351 51.49742)
# Name: geometry, Length: 22255, dtype: geometry

# %% [markdown]
# ### Geopandas and folium plots

# %%
rest_name = input('Enter name of restaurant: ')
rest_name_gdf = gdf[gdf['BusinessName'].str.contains(rest_name)]
if len(rest_name_gdf) == 0:
    print(f'There were {len(rest_name_gdf)} {rest_name} restaurants found.')
else:
    print(f'There were {len(rest_name_gdf)} {rest_name} restaurants found which are shown below in the plot')
    ax = london_new.plot(edgecolor='#F1C40F',color='#F1C40F', alpha=0.5)
    rest_name_gdf.plot(ax=ax, marker='*', color='red')
    legend_drawn_flag = True
    plt.legend([f'{rest_name} restaurants'], frameon=legend_drawn_flag)

    #Adding north arrow
    x, y, arrow_length = 0.035, 0.96, 0.09
    ax.annotate('N', xy=(x, y), xytext=(x, y-arrow_length),
                arrowprops=dict(facecolor='black', width=15, headwidth=35),
                ha='center', va='center', fontsize=20,
                xycoords=ax.transAxes) 


    #Adding scalebar
    scalebar = ScaleBar(2, "cm", length_fraction=0.25, location='lower center')
    ax.add_artist(scalebar) 
    plt.rcParams['figure.figsize']= [8, 8]
# Out:
# Enter name of restaurant: thai
# There were 15 thai restaurants found which are shown below in the plot

# %% [markdown]
# map2 = folium.Map(location=[51.51363, -0.09599], tiles="cartodbpositron", zoom_start=10, )
# add_markers_to_the_map(map2, rest_name_pjtd, color = 'orange', icon='gg-circle')

# %% [markdown]
# ### Buffer plot around point of interest

# %%
rest_name_gdf.loc[[2360]].BusinessName
# Out:
# 2360    Grabthai Bangkok Cafe
# Name: BusinessName, dtype: object

# %% [markdown]
# Drawing a buffer of 1000m around Grabthai Bangkok Cafe(our point of interest) to locate other thai restaurants within this area. The best way to visualize this buffer is in folium as it is more interactive...

# %%
rest_name_gdf.loc[[2360]].geometry
# Out:
# 2360    POINT (-0.09599 51.51363)
# Name: geometry, dtype: geometry

# %%
buf1000_gdf = gpd.GeoDataFrame(geometry = rest_name_gdf.loc[[2360]]['geometry'].to_crs('epsg:27700').buffer(1000), 
                           crs='epsg:27700')
ax2 = buf1000_gdf.plot(color='purple')
london.plot(ax=ax2, edgecolor='#F1C40F',color='#F1C40F', alpha=0.1) #using the london gdf as its coordinates are projected
# Out:
# <AxesSubplot:>

# %%
rest_name_gdf.crs #crs is wgs84
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# #### Because buffers and distance calculations are better using projected coordinate system(crs), rest_name_gdf crs must be converted

# %%
buf1000_gdf.crs
# Out:
# <Projected CRS: EPSG:27700>
# Name: OSGB 1936 / British National Grid
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: UK - Britain and UKCS 49°46'N to 61°01'N, 7°33'W to 3°33'E
# - bounds: (-9.2, 49.75, 2.88, 61.14)
# Coordinate Operation:
# - name: British National Grid
# - method: Transverse Mercator
# Datum: OSGB 1936
# - Ellipsoid: Airy 1830
# - Prime Meridian: Greenwich

# %%
intersection_MeshBlock = gpd.overlay(rest_name_gdf.to_crs('epsg:27700'), 
                                     buf1000_gdf, 
                                     how="intersection")
intersection_MeshBlock.plot()
# Out:
# <AxesSubplot:>

# %%
intersection_MeshBlock
# Out:
#                         _id                BusinessName RatingValue  \
# 0  620cd57eaa28c13b7950ba30       Grabthai Bangkok Cafe           4
# 1  620cd57eaa28c13b7950ba2d  Grab Food Ltd T/A Grabthai           4
#
#        AddressLine2  PostCode  Geocode_Longitude  Geocode_Latitude  \
# 0            London  EC4M 9AG          -0.095991         51.513632
# 1  148 Fleet Street  EC4A 2BU          -0.107388         51.514392
#
#                         geometry
# 0  POINT (532218.105 181130.058)
# 1  POINT (531425.133 181194.059)

# %% [markdown]
# rest_name_pjtd = rest_name_gdf.to_crs('epsg:27700')
# rest_name_pjtd.head()

# %% [markdown]
# ### Distance Function

# %%
rest_name_gdf.to_crs('epsg:27700').head()
# Out:
#                            _id           BusinessName RatingValue  \
# 2360  620cd57eaa28c13b7950ba30  Grabthai Bangkok Cafe           4
# 3544  620cd590aa28c13b7951c773          Busaba Eathai           5
# 7111  620cd5a5aa28c13b7952f360          Busaba Eathai           3
# 7112  620cd5a5aa28c13b7952f363          Busaba Eathai           5
# 7113  620cd5a5aa28c13b7952f366          Busaba Eathai           2
#
#      AddressLine2  PostCode  Geocode_Longitude  Geocode_Latitude  \
# 2360       London  EC4M 9AG          -0.095991         51.513632
# 3544       LONDON   SW3 5UZ          -0.176735         51.484206
# 7111       London   W1F 0AS          -0.137651         51.513151
# 7112       London  WC2E 9DA          -0.123613         51.513070
# 7113       London   W1W 8ED          -0.138539         51.516376
#
#                            geometry
# 2360  POINT (532218.105 181130.058)
# 3544  POINT (526697.124 177715.099)
# 7111  POINT (529328.860 181002.185)
# 7112  POINT (530303.139 181018.059)
# 7113  POINT (529258.121 181359.305)

# %%
gdf.head()
# Out:
#                         _id          BusinessName         RatingValue  \
# 0  620cd586aa28c13b79512f6f      101 Thai Kitchen                   3
# 1  620cd586aa28c13b79512f75    2020 Mezza & Grill  AwaitingInspection
# 2  620cd586aa28c13b79512f78  222 Vegan Restaurant                   3
# 3  620cd586aa28c13b79512f7b    24 / 7 Supermarket                   3
# 4  620cd586aa28c13b79512f7e            696 Mangal                   5
#
#   AddressLine2 PostCode  Geocode_Longitude  Geocode_Latitude  \
# 0       London   W6 0RX          -0.244311         51.493618
# 1       London   W6 9PL          -0.222939         51.488278
# 2       London  W14 9NU          -0.202997         51.485879
# 3       London   W6 0QU          -0.232831         51.492834
# 4       London  SW6 5SA          -0.206834         51.474724
#
#                     geometry
# 0  POINT (-0.24431 51.49362)
# 1  POINT (-0.22294 51.48828)
# 2  POINT (-0.20300 51.48588)
# 3  POINT (-0.23283 51.49283)
# 4  POINT (-0.20683 51.47472)

# %%
gdf.to_crs('epsg:27700').head()
# Out:
#                         _id          BusinessName         RatingValue  \
# 0  620cd586aa28c13b79512f6f      101 Thai Kitchen                   3
# 1  620cd586aa28c13b79512f75    2020 Mezza & Grill  AwaitingInspection
# 2  620cd586aa28c13b79512f78  222 Vegan Restaurant                   3
# 3  620cd586aa28c13b79512f7b    24 / 7 Supermarket                   3
# 4  620cd586aa28c13b79512f7e            696 Mangal                   5
#
#   AddressLine2 PostCode  Geocode_Longitude  Geocode_Latitude  \
# 0       London   W6 0RX          -0.244311         51.493618
# 1       London   W6 9PL          -0.222939         51.488278
# 2       London  W14 9NU          -0.202997         51.485879
# 3       London   W6 0QU          -0.232831         51.492834
# 4       London  SW6 5SA          -0.206834         51.474724
#
#                         geometry
# 0  POINT (521980.141 178647.082)
# 1  POINT (523478.138 178089.047)
# 2  POINT (524869.160 177856.062)
# 3  POINT (522779.154 178579.072)
# 4  POINT (524633.142 176609.049)

# %%
gdf.crs='epsg:4326'
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# LineString(coordinates = [gdf.loc[0].geometry, gdf.loc[1].geometry])
# round(gdf.to_crs('epsg:27700').loc[0].geometry.distance(gdf.to_crs('epsg:27700').loc[1].geometry), 3)

# %%
a = gdf.loc[[0]]
a
b = gdf.loc[[1]]
b
# Out:
#                         _id        BusinessName         RatingValue  \
# 1  620cd586aa28c13b79512f75  2020 Mezza & Grill  AwaitingInspection
#
#   AddressLine2 PostCode  Geocode_Longitude  Geocode_Latitude  \
# 1       London   W6 9PL          -0.222939         51.488278
#
#                     geometry
# 1  POINT (-0.22294 51.48828)

# %%
LineString(coordinates = [Point(zip(gdf.loc[[0]].Geocode_Longitude, gdf.loc[[0]].Geocode_Latitude)), Point(zip(gdf.loc[[1]].Geocode_Longitude, gdf.loc[[1]].Geocode_Latitude))])

# %%
gdf.crs='epsg:27700'
gdf.crs
# Out:
# <Projected CRS: EPSG:27700>
# Name: OSGB 1936 / British National Grid
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: UK - Britain and UKCS 49°46'N to 61°01'N, 7°33'W to 3°33'E
# - bounds: (-9.2, 49.75, 2.88, 61.14)
# Coordinate Operation:
# - name: British National Grid
# - method: Transverse Mercator
# Datum: OSGB 1936
# - Ellipsoid: Airy 1830
# - Prime Meridian: Greenwich

# %%
def create_linestring_gdf(gdframe, epsg=27700):
    """This function creates a line geodataframe from a point geodataframe"""
    gdframe = gdframe.reset_index(drop=True)
    gdframe = gdframe.drop(["geometry"], axis=1)
    indexes = gdframe.index.to_list()
    crs_info = int(input('What crs information would you like?\n1. WGS84'
                         '\n2. Projected CRS with epsg value passed: '))
    if crs_info == 1:
        linestrings = []
        for i in range(len(indexes)):
            a_lon, a_lat = gdframe.loc[indexes[i-1]].Geocode_Longitude, gdframe.loc[indexes[i-1]].Geocode_Latitude
            b_lon, b_lat = gdframe.loc[indexes[i]].Geocode_Longitude, gdframe.loc[indexes[i]].Geocode_Latitude
            linestrings.append(LineString(coordinates = [Point(a_lat, a_lon), Point(b_lat, b_lon)]))
        gdframe['geometry'] = linestrings                           
    
    elif crs_info == 2:
        linestrings = []
        transformer = Transformer.from_crs(4326, epsg)
        
        for i in range(len(indexes)):
            a_lon, a_lat = gdframe.loc[indexes[i-1]].Geocode_Longitude, gdframe.loc[indexes[i-1]].Geocode_Latitude
            b_lon, b_lat = gdframe.loc[indexes[i]].Geocode_Longitude, gdframe.loc[indexes[i]].Geocode_Latitude
            a_transformed = transformer.transform(a_lat, a_lon)
            b_transformed = transformer.transform(b_lat, b_lon)
            linestrings.append(LineString(coordinates = [Point(a_transformed[0], a_transformed[1]), Point(b_transformed[0], b_transformed[1])]))
        gdframe['geometry'] = linestrings    

        
    return gdframe


def calc_dist_bw_pts_in(gdframe, epsg):
    """Calculates the euclidian distance(saved in a new column called distances) between the previous point and the current point in the point dataframe passed
       First argument that must be passed is the point dataframe
       Second argument that must be passed is the epsg code, since for proper distance calculations, WGS84 coordinates must be converted to projected coordinates"""
    
    gdframe = gdframe.reset_index(drop=True)
    indexes = gdframe.index.to_list()
    distances = []
    option = int(input('Select an option'+
                       '\n1. LineStrings gdf with WGS84 crs'+
                       '\n2. LineString gdf with OSGB(epsg:27700) crs\n'))
    
    if option == 1: #geometry of line gdf must be converted from WGS84 to projected depeding on epsg that the user passes
        for i in range(len(indexes)):
            distances.append(round(gdframe.to_crs(f'epsg:{epsg}').loc[indexes[i-1]].geometry.distance(gdframe.to_crs(f'epsg:{epsg}').loc[indexes[i]].geometry), 2))                  
        gdframe['distances']=distances                    

    elif option == 2:
        for i in range(len(indexes)):
            distances.append(round(gdframe.loc[i]['geometry'].length, 2))                 
        gdframe['distances']=distances  
    
    return gdframe

# %%
line = create_linestring_gdf(intersection_MeshBlock)
line = calc_dist_bw_pts_in(line, epsg=27700)
line
# Out:
# What crs information would you like?
# 1. WGS84
# 2. Projected CRS with epsg value passed: 2
# Select an option
# 1. LineStrings gdf with WGS84 crs
# 2. LineString gdf with OSGB(epsg:27700) crs
# 2
#                         _id                BusinessName RatingValue  \
# 0  620cd57eaa28c13b7950ba30       Grabthai Bangkok Cafe           4
# 1  620cd57eaa28c13b7950ba2d  Grab Food Ltd T/A Grabthai           4
#
#        AddressLine2  PostCode  Geocode_Longitude  Geocode_Latitude  \
# 0            London  EC4M 9AG          -0.095991         51.513632
# 1  148 Fleet Street  EC4A 2BU          -0.107388         51.514392
#
#                                             geometry  distances
# 0  LINESTRING (531425.133 181194.059, 532218.105 ...     795.55
# 1  LINESTRING (532218.105 181130.058, 531425.133 ...     795.55

# %%
intersection_MeshBlock
# Out:
#                         _id                BusinessName RatingValue  \
# 0  620cd57eaa28c13b7950ba30       Grabthai Bangkok Cafe           4
# 1  620cd57eaa28c13b7950ba2d  Grab Food Ltd T/A Grabthai           4
#
#        AddressLine2  PostCode  Geocode_Longitude  Geocode_Latitude  \
# 0            London  EC4M 9AG          -0.095991         51.513632
# 1  148 Fleet Street  EC4A 2BU          -0.107388         51.514392
#
#                         geometry
# 0  POINT (532218.105 181130.058)
# 1  POINT (531425.133 181194.059)

# %%
line
# Out:
#                         _id                BusinessName RatingValue  \
# 0  620cd57eaa28c13b7950ba30       Grabthai Bangkok Cafe           4
# 1  620cd57eaa28c13b7950ba2d  Grab Food Ltd T/A Grabthai           4
#
#        AddressLine2  PostCode  Geocode_Longitude  Geocode_Latitude  \
# 0            London  EC4M 9AG          -0.095991         51.513632
# 1  148 Fleet Street  EC4A 2BU          -0.107388         51.514392
#
#                                             geometry  distances
# 0  LINESTRING (531425.133 181194.059, 532218.105 ...     795.55
# 1  LINESTRING (532218.105 181130.058, 531425.133 ...     795.55

# %%
line.loc[1]['geometry']

# %%
line.loc[0]
# Out:
# _id                                           620cd57eaa28c13b7950ba30
# BusinessName                                     Grabthai Bangkok Cafe
# RatingValue                                                          4
# AddressLine2                                                    London
# PostCode                                                      EC4M 9AG
# Geocode_Longitude                                            -0.095991
# Geocode_Latitude                                               51.5136
# geometry             LINESTRING (531425.1327309737 181194.059220527...
# distances                                                       795.55
# Name: 0, dtype: object

# %% [markdown]
# line.plot?

# %%
ax3 = buf1000_gdf.plot(alpha=0.1)
intersection_MeshBlock.plot(ax=ax3)
line.plot(ax=ax3, color='black', legend=True)
# legend_drawn_flag = True
# plt.legend(['Euclidean distance'], frameon=legend_drawn_flag)
# Out:
# <AxesSubplot:>

# %%
buf1000_gdf.geometry.centroid ##returns the centroid
# Out:
# 2360    POINT (532218.105 181130.058)
# dtype: geometry

# %%
# rest_name_gdf
# restaurants = rest_name_gdf['geometry'].to_json()
# restaurants = folium.features.GeoJson(restaurants)
# my_map.add_child(restaurants)
# my_map 
my_map = folium.Map(location=[51.5074, 0.1272], tiles="OpenStreetMap", zoom_start=11,)
def add_markers_to_the_map(map_object, gdf, color, icon=None):  
    points = list(zip(zip(gdf.Geocode_Latitude, gdf.Geocode_Longitude),
                      gdf.BusinessName, 
                      gdf.RatingValue, 
                      gdf.PostCode))
    for point in points:         
            html =f"Name: {point[1]} <br>RatingValue: {str(point[2])} <br>PostCode: {point[3]}"
        
#           popup = folium.Popup(popup_text, autopan='False', parse_html=True, max_width=500)
            
            iframe= folium.IFrame(html)
            popup = folium.Popup(iframe,
                    min_width=250, 
                    max_width=250, 
                    parse_html=True)
            
            marker = folium.Marker(location=point[0], 
                                   popup=popup).add_to(map_object)
    return map_object

add_markers_to_the_map(my_map, rest_name_gdf, color = 'black', icon='gg-circle')

buf_1000m = folium.Circle(location=[rest_name_gdf.loc[2360].Geocode_Latitude, 
               rest_name_gdf.loc[2360].Geocode_Longitude], 
               radius=1000, #1000m radius
               color='green', 
               fill=True, 
               opacity=0.1,
               fill_opacity=0.6)
buf_1000m.add_to(my_map)

buf_4000m = folium.Circle(location=[rest_name_gdf.loc[2360].Geocode_Latitude, 
               rest_name_gdf.loc[2360].Geocode_Longitude], 
               radius=4000, #1000m radius
               color='yellow', 
               fill=True, 
               opacity=0.1,
               fill_opacity=0.4)
buf_4000m.add_to(my_map)

folium.PolyLine(locations=[(line.loc[0].Geocode_Latitude, line.loc[0].Geocode_Longitude), 
                           (line.loc[1].Geocode_Latitude, line.loc[1].Geocode_Longitude)], 
                tooltip=f"{round(line.loc[[0]].distances[0],2)}").add_to(my_map)

my_map #we can see the restaurants within our area of interest, together with thwir popups
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_40fe69b59563e0c57595dfacdf75c414 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_40fe69b59563e0c57595dfacdf75c414&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_40fe69b59563e0c57595dfacdf75c414 = L.map(
#                 &quot;map_40fe69b59563e0c57595dfacdf75c414&quot;,
#                 {
#                     center: [51.5074, 0.1272],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_98b6221c540e61c1e4cc9b628cb82527 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_40fe69b59563e0c57595dfacdf75c414);
#
#
#             var marker_2693ba179ad840513dcae5f929d176ae = L.marker(
#                 [51.513632, -0.09599099999999999],
#                 {}
#             ).addTo(map_40fe69b59563e0c57595dfacdf75c414);
#
#
#         var popup_667368e0465e985e9e5af45401ccf7ca = L.popup({&quot;maxWidth&quot;: 250, &quot;minWidth&quot;: 250});
#
#
#             var i_frame_111bccb08be800a5c9880866b83981d6 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBOYW1lOiBHcmFidGhhaSBCYW5na29rIENhZmUgPGJyPlJhdGluZ1ZhbHVlOiA0IDxicj5Qb3N0Q29kZTogRUM0TSA5QUc=&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_667368e0465e985e9e5af45401ccf7ca.setContent(i_frame_111bccb08be800a5c9880866b83981d6);
#
#
#         marker_2693ba179ad840513dcae5f929d176ae.bindPopup(popup_667368e0465e985e9e5af45401ccf7ca)
#         ;
#
#
#
#
#             var marker_a4d2a83c2849bf6929dbd88e2b853514 = L.marker(
#                 [51.484206, -0.176735],
#                 {}
#             ).addTo(map_40fe69b59563e0c57595dfacdf75c414);
#
#
#         var popup_08df6aaeec3abfc0fb2dffee89163fc1 = L.popup({&quot;maxWidth&quot;: 250, &quot;minWidth&quot;: 250});
#
#
#             var i_frame_b4246954d1109ba4919f36b75cf25b35 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBOYW1lOiBCdXNhYmEgRWF0aGFpIDxicj5SYXRpbmdWYWx1ZTogNSA8YnI+UG9zdENvZGU6IFNXMyA1VVo=&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_08df6aaeec3abfc0fb2dffee89163fc1.setContent(i_frame_b4246954d1109ba4919f36b75cf25b35);
#
#
#         marker_a4d2a83c2849bf6929dbd88e2b853514.bindPopup(popup_08df6aaeec3abfc0fb2dffee89163fc1)
#         ;
#
#
#
#
#             var marker_d9ff1ab2b75d1af76fe66a9034683f95 = L.marker(
#                 [51.513151, -0.137651],
#                 {}
#             ).addTo(map_40fe69b59563e0c57595dfacdf75c414);
#
#
#         var popup_b27fa2eb29526386cac39aeab69abe69 = L.popup({&quot;maxWidth&quot;: 250, &quot;minWidth&quot;: 250});
#
#
#             var i_frame_c6bfa43b34703a6dcc15a3aeb060bed2 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBOYW1lOiBCdXNhYmEgRWF0aGFpIDxicj5SYXRpbmdWYWx1ZTogMyA8YnI+UG9zdENvZGU6IFcxRiAwQVM=&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_b27fa2eb29526386cac39aeab69abe69.setContent(i_frame_c6bfa43b34703a6dcc15a3aeb060bed2);
#
#
#         marker_d9ff1ab2b75d1af76fe66a9034683f95.bindPopup(popup_b27fa2eb29526386cac39aeab69abe69)
#         ;
#
#
#
#
#             var marker_54e79ccc6b5c81bbb9ba11538e3c52f1 = L.marker(
#                 [51.51307, -0.12361300000000001],
#                 {}
#             ).addTo(map_40fe69b59563e0c57595dfacdf75c414);
#
#
#         var popup_2287c487308aa192a4baf1ee9153250b = L.popup({&quot;maxWidth&quot;: 250, &quot;minWidth&quot;: 250});
#
#
#             var i_frame_340820c113749b1b66accb120f6d9be4 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBOYW1lOiBCdXNhYmEgRWF0aGFpIDxicj5SYXRpbmdWYWx1ZTogNSA8YnI+UG9zdENvZGU6IFdDMkUgOURB&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_2287c487308aa192a4baf1ee9153250b.setContent(i_frame_340820c113749b1b66accb120f6d9be4);
#
#
#         marker_54e79ccc6b5c81bbb9ba11538e3c52f1.bindPopup(popup_2287c487308aa192a4baf1ee91

# %% [markdown]
# #### Finding the distances between all points in 'buf_4000m'(the yellow buffered area in the folium plot above)
# #### What will be done
# - 1. Gdf containing the intersection of the the yellow buffered area and the points that fall within that area, will be created
# - 2. The line gdf is created from the point gdf in step1
# - 3. The euclidean distances between all points in the gdf will be calculated using the function created above (calc_dist_bw_pts_in)
# - 4. It is finally plotted on the folium plot

# %%
buf_4000m

# %%
buf4000_gdf = gpd.GeoDataFrame(geometry = rest_name_gdf.loc[[2360]]['geometry'].to_crs('epsg:27700').buffer(4000), 
                           crs='epsg:27700')
buf4000_gdf.plot(color='#F9D742', alpha=0.75)
# Out:
# <AxesSubplot:>

# %%
intersectn_restgdf_400buf = gpd.overlay(rest_name_gdf.to_crs('epsg:27700'), 
                                     buf4000_gdf, 
                                     how="intersection")
intersectn_restgdf_400buf.plot(color='black')
# Out:
# <AxesSubplot:>

# %%
points_in_400m_buf = create_linestring_gdf(intersectn_restgdf_400buf)
points_in_400m_buf
# Out:
# What crs information would you like?
# 1. WGS84
# 2. Projected CRS with epsg value passed: 2
#                         _id                BusinessName RatingValue  \
# 0  620cd57eaa28c13b7950ba30       Grabthai Bangkok Cafe           4
# 1  620cd5a5aa28c13b7952f360               Busaba Eathai           3
# 2  620cd5a5aa28c13b7952f363               Busaba Eathai           5
# 3  620cd5a5aa28c13b7952f366               Busaba Eathai           2
# 4  620cd5a5aa28c13b7952f369               Busaba Eathai           5
# 5  620cd57eaa28c13b7950ba2d  Grab Food Ltd T/A Grabthai           4
# 6  620cd585aa28c13b79511a21           Busaba Eathai Ltd           5
# 7  620cd59faa28c13b7952a25d           Busaba Eathai Ltd           5
# 8  620cd5a5aa28c13b7952f36c               Busaba Eathai           5
#
#                              AddressLine2  PostCode  Geocode_Longitude  \
# 0                                  London  EC4M 9AG          -0.095991
# 1                                  London   W1F 0AS          -0.137651
# 2                                  London  WC2E 9DA          -0.123613
# 3                                  London   W1W 8ED          -0.138539
# 4                                  London   W1U 1BU          -0.151189
# 5                        148 Fleet Street  EC4A 2BU          -0.107388
# 6                      313-319 Old Street  EC1V 9LE          -0.080650
# 7  3 Innova Passage/36 Bethnal Green Road    E1 6LJ          -0.069962
# 8                     32-34 Panton Street  SW1Y 4EA          -0.131393
#
#    Geocode_Latitude                                           geometry
# 0         51.513632  LINESTRING (529772.755 180635.207, 532218.105 ...
# 1         51.513151  LINESTRING (532218.105 181130.058, 529328.860 ...
# 2         51.513070  LINESTRING (529328.860 181002.185, 530303.139 ...
# 3         51.516376  LINESTRING (530303.139 181018.059, 529258.121 ...
# 4         51.514713  LINESTRING (529258.121 181359.305, 528385.116 ...
# 5         51.514392  LINESTRING (528385.116 181152.068, 531425.133 ...
# 6         51.527141  LINESTRING (531425.133 181194.059, 533243.143 ...
# 7         51.525646  LINESTRING (533243.143 182660.104, 533988.913 ...
# 8         51.509751  LINESTRING (533988.913 182513.303, 529772.755 ...

# %%
lines_in400m_buf = calc_dist_bw_pts_in(points_in_400m_buf, epsg=27700)
lines_in400m_buf
# Out:
# Select an option
# 1. LineStrings gdf with WGS84 crs
# 2. LineString gdf with OSGB(epsg:27700) crs
# 2
#                         _id                BusinessName RatingValue  \
# 0  620cd57eaa28c13b7950ba30       Grabthai Bangkok Cafe           4
# 1  620cd5a5aa28c13b7952f360               Busaba Eathai           3
# 2  620cd5a5aa28c13b7952f363               Busaba Eathai           5
# 3  620cd5a5aa28c13b7952f366               Busaba Eathai           2
# 4  620cd5a5aa28c13b7952f369               Busaba Eathai           5
# 5  620cd57eaa28c13b7950ba2d  Grab Food Ltd T/A Grabthai           4
# 6  620cd585aa28c13b79511a21           Busaba Eathai Ltd           5
# 7  620cd59faa28c13b7952a25d           Busaba Eathai Ltd           5
# 8  620cd5a5aa28c13b7952f36c               Busaba Eathai           5
#
#                              AddressLine2  PostCode  Geocode_Longitude  \
# 0                                  London  EC4M 9AG          -0.095991
# 1                                  London   W1F 0AS          -0.137651
# 2                                  London  WC2E 9DA          -0.123613
# 3                                  London   W1W 8ED          -0.138539
# 4                                  London   W1U 1BU          -0.151189
# 5                        148 Fleet Street  EC4A 2BU          -0.107388
# 6                      313-319 Old Street  EC1V 9LE          -0.080650
# 7  3 Innova Passage/36 Bethnal Green Road    E1 6LJ          -0.069962
# 8                     32-34 Panton Street  SW1Y 4EA          -0.131393
#
#    Geocode_Latitude                                           geometry  \
# 0         51.513632  LINESTRING (529772.755 180635.207, 532218.105 ...
# 1         51.513151  LINESTRING (532218.105 181130.058, 529328.860 ...
# 2         51.513070  LINESTRING (529328.860 181002.185, 530303.139 ...
# 3         51.516376  LINESTRING (530303.139 181018.059, 529258.121 ...
# 4         51.514713  LINESTRING (529258.121 181359.305, 528385.116 ...
# 5         51.514392  LINESTRING (528385.116 181152.068, 531425.133 ...
# 6         51.527141  LINESTRING (531425.133 181194.059, 533243.143 ...
# 7         51.525646  LINESTRING (533243.143 182660.104, 533988.913 ...
# 8         51.509751  LINESTRING (533988.913 182513.303, 529772.755 ...
#
#    distances
# 0    2494.92
# 1    2892.07
# 2     974.41
# 3    1099.32
# 4     897.27
# 5    3040.31
# 6    2335.48
# 7     760.08
# 8    4615.54

# %%
lines_in400m_buf.plot(color='black')
# Out:
# <AxesSubplot:>

# %%
# rest_name_gdf
# restaurants = rest_name_gdf['geometry'].to_json()
# restaurants = folium.features.GeoJson(restaurants)
# my_map.add_child(restaurants)
# my_map 
#functions

def add_markers_to_the_map(map_object, gdf, colour, icon=None):  
    """Takes map_object(folium map), geodataframe, colour and icon and creates a improved folium map 
       with additional features(popups at the locations in the geodataframe with colour passed)"""
    points = list(zip(zip(gdf.Geocode_Latitude, gdf.Geocode_Longitude),
                      gdf.BusinessName, 
                      gdf.RatingValue, 
                      gdf.PostCode))
    for point in points:         
            html =f"Name: {point[1]} <br>RatingValue: {str(point[2])} <br>PostCode: {point[3]}"
#           popup = folium.Popup(popup_text, autopan='False', parse_html=True, max_width=500)
            
            iframe= folium.IFrame(html)
            popup = folium.Popup(iframe,
                    min_width=250, 
                    max_width=250, 
                    parse_html=True)
            
            marker = folium.Marker(location=point[0], 
                                   popup=popup, 
                                   #icon=folium.Icon(icon_size=(25, 25), color=colour, icon=icon, prefix='fa')).add_to(map_object)
                                  ).add_to(map_object)
    return map_object

def add_lines_to(map_object, line_gdf, color):
    """Takes folim  map and line geodataframe and adds line plot on folium map with their corresponding distances shown on tooltp"""
    indexes = line_gdf.index.to_list()
    for i in range(len(indexes)):
        loc = [(line_gdf.loc[indexes[i-1]].Geocode_Latitude, line_gdf.loc[indexes[i-1]].Geocode_Longitude), 
               (line_gdf.loc[indexes[i]].Geocode_Latitude, line_gdf.loc[indexes[i]].Geocode_Longitude)]
        folium.PolyLine(locations=loc, color=color,
                        tooltip=line_gdf.loc[[i]].distances[i]).add_to(map_object)
    return map_object
    
my_map = folium.Map(location=[51.5074, 0.1272], tiles="OpenStreetMap", zoom_start=11,)
add_markers_to_the_map(my_map, rest_name_gdf, colour = 'black', icon=None) #calling the function

buf_1000m = folium.Circle(location=[rest_name_gdf.loc[2360].Geocode_Latitude, 
               rest_name_gdf.loc[2360].Geocode_Longitude], 
               radius=1000, #1000m radius
               color='green', 
               fill=True, 
               opacity=0.1,
               fill_opacity=0.6)
buf_1000m.add_to(my_map)

buf_4000m = folium.Circle(location=[rest_name_gdf.loc[2360].Geocode_Latitude, 
               rest_name_gdf.loc[2360].Geocode_Longitude], 
               radius=4000, #1000m radius
               color='yellow', 
               fill=True, 
               opacity=0.1,
               fill_opacity=0.4)
buf_4000m.add_to(my_map)

add_lines_to(my_map, line, color='red')
add_lines_to(my_map, lines_in400m_buf, 'black')

draw = Draw()
draw.add_to(my_map)  #This gives the user the opportunity to draw on the map
folium.LayerControl(collapsed=False).add_to(my_map)
my_map
# my_map #we can see the restaurants within our area of interest, together with lines connecting them and their popups
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b2c3bf051945c89fe26e696e11f7b9e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b2c3bf051945c89fe26e696e11f7b9e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b2c3bf051945c89fe26e696e11f7b9e9 = L.map(
#                 &quot;map_b2c3bf051945c89fe26e696e11f7b9e9&quot;,
#                 {
#                     center: [51.5074, 0.1272],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d0b7c29d900ec3f413b5e5844510e307 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b2c3bf051945c89fe26e696e11f7b9e9);
#
#
#             var marker_00cebd5808b31a7c4af65da3053e28b1 = L.marker(
#                 [51.513632, -0.09599099999999999],
#                 {}
#             ).addTo(map_b2c3bf051945c89fe26e696e11f7b9e9);
#
#
#         var popup_5608d8ce3a4c7f7ce2133f0170ae14a3 = L.popup({&quot;maxWidth&quot;: 250, &quot;minWidth&quot;: 250});
#
#
#             var i_frame_0a6e979bf31c4ba44eb04f93e52823b0 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBOYW1lOiBHcmFidGhhaSBCYW5na29rIENhZmUgPGJyPlJhdGluZ1ZhbHVlOiA0IDxicj5Qb3N0Q29kZTogRUM0TSA5QUc=&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_5608d8ce3a4c7f7ce2133f0170ae14a3.setContent(i_frame_0a6e979bf31c4ba44eb04f93e52823b0);
#
#
#         marker_00cebd5808b31a7c4af65da3053e28b1.bindPopup(popup_5608d8ce3a4c7f7ce2133f0170ae14a3)
#         ;
#
#
#
#
#             var marker_0f3061dce2b55534a3e7d4b1c9da24a8 = L.marker(
#                 [51.484206, -0.176735],
#                 {}
#             ).addTo(map_b2c3bf051945c89fe26e696e11f7b9e9);
#
#
#         var popup_92623078bd7150dbc7c7f9550f6eee17 = L.popup({&quot;maxWidth&quot;: 250, &quot;minWidth&quot;: 250});
#
#
#             var i_frame_0e25f04b03447bdcd2f459db5fb583a6 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBOYW1lOiBCdXNhYmEgRWF0aGFpIDxicj5SYXRpbmdWYWx1ZTogNSA8YnI+UG9zdENvZGU6IFNXMyA1VVo=&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_92623078bd7150dbc7c7f9550f6eee17.setContent(i_frame_0e25f04b03447bdcd2f459db5fb583a6);
#
#
#         marker_0f3061dce2b55534a3e7d4b1c9da24a8.bindPopup(popup_92623078bd7150dbc7c7f9550f6eee17)
#         ;
#
#
#
#
#             var marker_ce734e580b2314c234a4f993473c3245 = L.marker(
#                 [51.513151, -0.137651],
#                 {}
#             ).addTo(map_b2c3bf051945c89fe26e696e11f7b9e9);
#
#
#         var popup_39b3a90ac3992eae90be2263de9a3610 = L.popup({&quot;maxWidth&quot;: 250, &quot;minWidth&quot;: 250});
#
#
#             var i_frame_ce4f1d36af1e7d3f402cddd81d07c1d3 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBOYW1lOiBCdXNhYmEgRWF0aGFpIDxicj5SYXRpbmdWYWx1ZTogMyA8YnI+UG9zdENvZGU6IFcxRiAwQVM=&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_39b3a90ac3992eae90be2263de9a3610.setContent(i_frame_ce4f1d36af1e7d3f402cddd81d07c1d3);
#
#
#         marker_ce734e580b2314c234a4f993473c3245.bindPopup(popup_39b3a90ac3992eae90be2263de9a3610)
#         ;
#
#
#
#
#             var marker_52bedcf39fe621e834f39626fe5f0656 = L.marker(
#                 [51.51307, -0.12361300000000001],
#                 {}
#             ).addTo(map_b2c3bf051945c89fe26e696e11f7b9e9);
#
#
#         var popup_401a31111f7a6e0ec851b23083dca61a = L.popup({&quot;maxWidth&quot;: 250, &quot;minWidth&quot;: 250});
#
#
#             var i_frame_f8990da05650e37a532cf5ee37cf291d = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBOYW1lOiBCdXNhYmEgRWF0aGFpIDxicj5SYXRpbmdWYWx1ZTogNSA8YnI+UG9zdENvZGU6IFdDMkUgOURB&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;

# %%
folium.Icon?

# %% [markdown]
# #### Alternatively,  the Draw function in folium has extra tools to calculate the distances between point, which is a simplification of the custom functions(create_linestring_gdf & calc_dist_bw_pts_in) created

# %% [markdown]
# #### Adding a convex hull to the plot to show the border of the region of interest

# %% [markdown]
# #### convex hull code adapted from https://fcpython.com/visualisation/convex-hulls-football-python

# %%
hull = ConvexHull(rest_name_gdf[['Geocode_Longitude','Geocode_Latitude']])
hull

# %%
rest_name_gdf.plot(color='black')
# Out:
# <AxesSubplot:>

# %%
rest_name_gdf.iloc[5]['Geocode_Longitude'], rest_name_gdf.iloc[5]['Geocode_Latitude']
# Out:
# (-0.15118900000000002, 51.514713)

# %%
hull.vertices
# Out:
# array([ 5,  1, 13,  6, 10,  9,  8], dtype=int32)

# %%
plt.plot(rest_name_gdf.Geocode_Longitude, rest_name_gdf.Geocode_Latitude, 'o', color='black')

#Loop through each of the hull's simplices
linepts = []
for simplex in hull.simplices:
    #Draw a black line between each
    linepts.append([(rest_name_gdf.iloc[simplex[0]]['Geocode_Latitude'], rest_name_gdf.iloc[simplex[0]]['Geocode_Longitude']), (rest_name_gdf.iloc[simplex[1]]['Geocode_Latitude'], rest_name_gdf.iloc[simplex[1]]['Geocode_Longitude'])])

    
linepts
# Out:
# [[(51.514713, -0.15118900000000002), (51.484206, -0.176735)],
#  [(51.434670000000004, -0.16203199999999998), (51.484206, -0.176735)],
#  [(51.434670000000004, -0.16203199999999998), (51.4112536, -0.1229287)],
#  [(51.508528999999996, -0.006439), (51.543299, 0.032606)],
#  [(51.508528999999996, -0.006439), (51.4112536, -0.1229287)],
#  [(51.527141, -0.08065), (51.543299, 0.032606)],
#  [(51.527141, -0.08065), (51.514713, -0.15118900000000002)]]

# %%
def PolyArea(x,y):
    return 0.5*np.abs(np.dot(x,np.roll(y,1))-np.dot(y,np.roll(x,1)))  #adapted from https://stackoverflow.com/questions/24467972/calculate-area-of-polygon-given-x-y-coordinates

# %% [markdown]
# folium.PolyLine?

# %%
for x in linepts:
       folium.PolyLine(locations=x).add_to(my_map)

# %%
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b2c3bf051945c89fe26e696e11f7b9e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b2c3bf051945c89fe26e696e11f7b9e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b2c3bf051945c89fe26e696e11f7b9e9 = L.map(
#                 &quot;map_b2c3bf051945c89fe26e696e11f7b9e9&quot;,
#                 {
#                     center: [51.5074, 0.1272],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d0b7c29d900ec3f413b5e5844510e307 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b2c3bf051945c89fe26e696e11f7b9e9);
#
#
#             var marker_00cebd5808b31a7c4af65da3053e28b1 = L.marker(
#                 [51.513632, -0.09599099999999999],
#                 {}
#             ).addTo(map_b2c3bf051945c89fe26e696e11f7b9e9);
#
#
#         var popup_5608d8ce3a4c7f7ce2133f0170ae14a3 = L.popup({&quot;maxWidth&quot;: 250, &quot;minWidth&quot;: 250});
#
#
#             var i_frame_0a6e979bf31c4ba44eb04f93e52823b0 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBOYW1lOiBHcmFidGhhaSBCYW5na29rIENhZmUgPGJyPlJhdGluZ1ZhbHVlOiA0IDxicj5Qb3N0Q29kZTogRUM0TSA5QUc=&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_5608d8ce3a4c7f7ce2133f0170ae14a3.setContent(i_frame_0a6e979bf31c4ba44eb04f93e52823b0);
#
#
#         marker_00cebd5808b31a7c4af65da3053e28b1.bindPopup(popup_5608d8ce3a4c7f7ce2133f0170ae14a3)
#         ;
#
#
#
#
#             var marker_0f3061dce2b55534a3e7d4b1c9da24a8 = L.marker(
#                 [51.484206, -0.176735],
#                 {}
#             ).addTo(map_b2c3bf051945c89fe26e696e11f7b9e9);
#
#
#         var popup_92623078bd7150dbc7c7f9550f6eee17 = L.popup({&quot;maxWidth&quot;: 250, &quot;minWidth&quot;: 250});
#
#
#             var i_frame_0e25f04b03447bdcd2f459db5fb583a6 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBOYW1lOiBCdXNhYmEgRWF0aGFpIDxicj5SYXRpbmdWYWx1ZTogNSA8YnI+UG9zdENvZGU6IFNXMyA1VVo=&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_92623078bd7150dbc7c7f9550f6eee17.setContent(i_frame_0e25f04b03447bdcd2f459db5fb583a6);
#
#
#         marker_0f3061dce2b55534a3e7d4b1c9da24a8.bindPopup(popup_92623078bd7150dbc7c7f9550f6eee17)
#         ;
#
#
#
#
#             var marker_ce734e580b2314c234a4f993473c3245 = L.marker(
#                 [51.513151, -0.137651],
#                 {}
#             ).addTo(map_b2c3bf051945c89fe26e696e11f7b9e9);
#
#
#         var popup_39b3a90ac3992eae90be2263de9a3610 = L.popup({&quot;maxWidth&quot;: 250, &quot;minWidth&quot;: 250});
#
#
#             var i_frame_ce4f1d36af1e7d3f402cddd81d07c1d3 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBOYW1lOiBCdXNhYmEgRWF0aGFpIDxicj5SYXRpbmdWYWx1ZTogMyA8YnI+UG9zdENvZGU6IFcxRiAwQVM=&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_39b3a90ac3992eae90be2263de9a3610.setContent(i_frame_ce4f1d36af1e7d3f402cddd81d07c1d3);
#
#
#         marker_ce734e580b2314c234a4f993473c3245.bindPopup(popup_39b3a90ac3992eae90be2263de9a3610)
#         ;
#
#
#
#
#             var marker_52bedcf39fe621e834f39626fe5f0656 = L.marker(
#                 [51.51307, -0.12361300000000001],
#                 {}
#             ).addTo(map_b2c3bf051945c89fe26e696e11f7b9e9);
#
#
#         var popup_401a31111f7a6e0ec851b23083dca61a = L.popup({&quot;maxWidth&quot;: 250, &quot;minWidth&quot;: 250});
#
#
#             var i_frame_f8990da05650e37a532cf5ee37cf291d = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBOYW1lOiBCdXNhYmEgRWF0aGFpIDxicj5SYXRpbmdWYWx1ZTogNSA8YnI+UG9zdENvZGU6IFdDMkUgOURB&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;

# %% [markdown]
# ### London Transport data -Tube

# %%
pd.read_csv('data/bus-stops-example.csv')
# Out:
#      Stop_Code_LBSL  Bus_Stop_Code Naptan_Atco  \
# 0             10001          72689  490013793E
# 1             10002          48461  490000108F
# 2             10003          77150  490000108B
# 3             10004          48037  490012451S
# 4             10005          57538  490012451N
# ..              ...            ...         ...
# 194           10880          53256  490010736G
# 195           10881          47221  490009248C
# 196           10883          75172  490006974A
# 197           10885          71425  490006974Z
# 198           10888          55929  490011855N
#
#                              Stop_Name  Location_Easting  Location_Northing  \
# 0                         TREVOR CLOSE            515781             174783
# 1                      HIGHBURY CORNER            531614             184603
# 2    HIGHBURY & ISLINGTON STATION <> #            531573             184786
# 3             ST MARY MAGDALENE CHURCH            531403             184942
# 4             ST MARY MAGDALENE CHURCH            531328             185009
# ..                                 ...               ...                ...
# 194       PALMERS GREEN / THE TRIANGLE            530996             192606
# 195                        LODGE DRIVE            531110             192821
# 196                           FOX LANE            531172             192966
# 197                           FOX LANE            531220             193067
# 198                 ST MONICA'S CHURCH            531418             193381
#
#      Heading Stop_Area  Virtual_Bus_Stop
# 0         78      NB16                 0
# 1          5      C902                 0
# 2        127      C903                 0
# 3        136      C904                 0
# 4        322      C904                 0
# ..       ...       ...               ...
# 194        6      U605                 0
# 195       26      U606                 0
# 196       19      U607                 0
# 197      199      U607                 0
# 198       62      U701                 0
#
# [199 rows x 9 columns]

# %% [markdown]
# url = 'https://api.tfl.gov.uk/Line/victoria/' #'https://api.tfl.gov.uk/Line/Mode/tube'
# response = requests.request("GET", url)
# print(response.text)

# %% [markdown]
# ### Using osmnx to obtain london network graph data

# %% [markdown]
# ox.graph_from_place?

# %% [markdown]
# place = ['London']
# G = ox.graph_from_place(place, retain_all=True, simplify = True, network_type='all')

# %% [markdown]
# fig, ax = ox.plot_graph(G, node_size=0,
#                         dpi = 100,bgcolor = bgcolor,
#                         save = False, edge_color=roadCols,
#                         edge_linewidth=1, edge_alpha=1)

# %% [markdown]
# ---------

# %% [markdown]
# ### Reading london tube data downloaded from https://www.doogal.co.uk/london_stations

# %%
tube_df = pd.read_csv('data/London_tube_lines.csv')
tube_df.head()
# Out:
#   Tube Line             From Station          To Station
# 0  Bakerloo             Baker Street        Regents Park
# 1  Bakerloo            Charing Cross          Embankment
# 2  Bakerloo  Edgware Road (Bakerloo)          Marylebone
# 3  Bakerloo               Embankment            Waterloo
# 4  Bakerloo                Harlesden  Willesden Junction

# %%
# gpd.read_file('London_Train_Lines.kml')

gpd.io.file.fiona.drvsupport.supported_drivers['KML'] = 'rw'
tube_linesgdf = gpd.read_file('data/London_Train_Lines.kml', driver='KML')
tube_linesgdf.head()
# Out:
#                                                Name Description  \
# 0           Bakerloo - Baker Street to Regents Park
# 1            Bakerloo - Charing Cross to Embankment
# 2  Bakerloo - Edgware Road (Bakerloo) to Marylebone
# 3                 Bakerloo - Embankment to Waterloo
# 4        Bakerloo - Harlesden to Willesden Junction
#
#                                             geometry
# 0  LINESTRING Z (-0.15690 51.52313 1.00000, -0.14...
# 1  LINESTRING Z (-0.12480 51.50836 1.00000, -0.12...
# 2  LINESTRING Z (-0.17054 51.52065 1.00000, -0.16...
# 3  LINESTRING Z (-0.12237 51.50731 1.00000, -0.11...
# 4  LINESTRING Z (-0.25750 51.53626 1.00000, -0.24...

# %%
# gpd.read_file('London_Train_Lines.kml')

gpd.io.file.fiona.drvsupport.supported_drivers['KML'] = 'rw'
tube_stnsgdf = gpd.read_file('data/london_tube_stations.kml', driver='KML')
tube_stnsgdf.head()
# Out:
#               Name                                        Description  \
# 0       Abbey Road  <div>Zone 3</div> <div>E15 3NB</div> <div>Lati...
# 1       Abbey Wood  <div>Zone 4</div> <div>SE2 9RH</div> <div>Lati...
# 2    Acton Central  <div>Zone 2</div> <div>W3 6BH</div> <div>Latit...
# 3  Acton Main Line  <div>Zone 3</div> <div>W3 9EH</div> <div>Latit...
# 4       Acton Town  <div>Zone 3</div> <div>W3 8HN</div> <div>Latit...
#
#                               geometry
# 0   POINT Z (0.00372 51.53195 0.00000)
# 1   POINT Z (0.12027 51.49078 0.00000)
# 2  POINT Z (-0.26343 51.50876 0.00000)
# 3  POINT Z (-0.26769 51.51689 0.00000)
# 4  POINT Z (-0.28030 51.50307 0.00000)

# %%
[i for i in tube_linesgdf.loc[[0]].geometry[0].coords]
# Out:
# [(-0.15690419298618452, 51.52312936605881, 1.0),
#  (-0.1453444097205957, 51.523810437772845, 1.0)]

# %%
tube_linesgdf.plot(color='red')
plt.title('London tube lines')
# Out:
# Text(0.5, 1.0, 'London tube lines')

# %%
#showing what the tube lines look like in the real world
tube_linesgdf.explore(color='red')  #if explore doesn't run update version of geopandas
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_feedc05dbc4dc307d4293886c92ea2b9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_feedc05dbc4dc307d4293886c92ea2b9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_feedc05dbc4dc307d4293886c92ea2b9 = L.map(
#                 &quot;map_feedc05dbc4dc307d4293886c92ea2b9&quot;,
#                 {
#                     center: [51.5145891244794, -0.32096267511551313],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_feedc05dbc4dc307d4293886c92ea2b9);
#
#
#
#
#
#             var tile_layer_b9691b4c45e0bca8d4951c74d8c63a80 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_feedc05dbc4dc307d4293886c92ea2b9);
#
#
#             map_feedc05dbc4dc307d4293886c92ea2b9.fitBounds(
#                 [[51.28216269622904, -0.9718776209963325], [51.747015552729756, 0.32995227076530625]],
#                 {}
#             );
#
#
#         function geo_json_916eea6aaee599536869478667ce99af_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_916eea6aaee599536869478667ce99af_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_916eea6aaee599536869478667ce99af_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_916eea6aaee599536869478667ce99af_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_916eea6aaee599536869478667ce99af_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_916eea6aaee599536869478667ce99af.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_916eea6aaee599536869478667ce99af_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_916eea6aaee599536869478667ce99af = L.geoJson(null, {
#                 onEachFeature: geo_json_916eea6aaee599536869478667ce99af_onEachFeature,
#
#                 style: geo_json_916eea6aaee599536869478667ce99af_styler,
#                 pointToLayer: geo_json_916eea6aaee599536869478667ce99af_pointToLayer
#         });
#
#         function geo_json_916eea6aaee599536869478667ce99af_add (data) {
#             geo_json_916eea6aaee599536869478667ce99af
#                 .addData(data)
#                 .addTo(map_feedc05dbc4dc307d4293886c92ea2b9);
#         }
#             geo_json_916eea6aaee599536869478667ce99af_add({&quot;bbox&quot;: [-0.9718776209963325, 51.28216269622904, 0.32995227076530625, 51.747015552729756], &quot;features&quot;: [{&quot;bbox&quot;: [-0.15690419298618452, 51.52312936605881, -0.1453444097205957, 51.523810437772845], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-0.15690419298618452, 51.52312936605881, 1.0], [-0.1453444097205957, 51.523810437772845, 1.0]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;Description&quot;: &quot;&quot;, &quot;Name&quot;: &quot;Bakerloo - Baker Street to Regents Park&quot;, &quot;__folium_color&quot;: &quot;red&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-0.124802

# %%
gpd.__version__
# Out:
# '0.10.2'

# %% [markdown]
# #### Obtaining from and to locations from tube lines to be added to a folium feature group

# %% [markdown]
# [list(tube_linesgdf.apply(lambda row: row.loc[[i for i in tube_linesgdf['indexx']]]).geometry[index_no].coords) for index_no in tube_linesgdf.index]

# %%
tube_stnsgdf.explore(color='red')  #showing what the points look like in the real world
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5e94f1cfd49ba42446f940e61c9340b8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5e94f1cfd49ba42446f940e61c9340b8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5e94f1cfd49ba42446f940e61c9340b8 = L.map(
#                 &quot;map_5e94f1cfd49ba42446f940e61c9340b8&quot;,
#                 {
#                     center: [51.5145895, -0.320963],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_5e94f1cfd49ba42446f940e61c9340b8);
#
#
#
#
#
#             var tile_layer_0b7857fda15e5589b458967d18c091b9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5e94f1cfd49ba42446f940e61c9340b8);
#
#
#             map_5e94f1cfd49ba42446f940e61c9340b8.fitBounds(
#                 [[51.282163, -0.971878], [51.747016, 0.329952]],
#                 {}
#             );
#
#
#         function geo_json_cf4539df0dbbb43bf554328ec94a89c3_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_cf4539df0dbbb43bf554328ec94a89c3_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_cf4539df0dbbb43bf554328ec94a89c3_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_cf4539df0dbbb43bf554328ec94a89c3_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_cf4539df0dbbb43bf554328ec94a89c3_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_cf4539df0dbbb43bf554328ec94a89c3.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_cf4539df0dbbb43bf554328ec94a89c3_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_cf4539df0dbbb43bf554328ec94a89c3 = L.geoJson(null, {
#                 onEachFeature: geo_json_cf4539df0dbbb43bf554328ec94a89c3_onEachFeature,
#
#                 style: geo_json_cf4539df0dbbb43bf554328ec94a89c3_styler,
#                 pointToLayer: geo_json_cf4539df0dbbb43bf554328ec94a89c3_pointToLayer
#         });
#
#         function geo_json_cf4539df0dbbb43bf554328ec94a89c3_add (data) {
#             geo_json_cf4539df0dbbb43bf554328ec94a89c3
#                 .addData(data)
#                 .addTo(map_5e94f1cfd49ba42446f940e61c9340b8);
#         }
#             geo_json_cf4539df0dbbb43bf554328ec94a89c3_add({&quot;bbox&quot;: [-0.971878, 51.282163, 0.329952, 51.747016], &quot;features&quot;: [{&quot;bbox&quot;: [0.003723, 51.531952, 0.003723, 51.531952], &quot;geometry&quot;: {&quot;coordinates&quot;: [0.003723, 51.531952, 0.0], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;Description&quot;: &quot;\u003cdiv\u003eZone 3\u003c/div\u003e \u003cdiv\u003eE15 3NB\u003c/div\u003e \u003cdiv\u003eLatitude: 51.531952\u003c/div\u003e \u003cdiv\u003eLongitude: 0.003723\u003c/div\u003e \u003cdiv\u003e \u003ca href=\&quot;https://www.doogal.co.uk/StationMap.php?station=Abbey Road\&quot;\u003eMore info\u003c/a\u003e \u003c/div\u003e&quot;, &quot;Name&quot;: &quot;Abbey Road&quot;, &quot;__folium_color&quot;

# %%
tube_stnsgdf.columns
# Out:
# Index(['Name', 'Description', 'geometry'], dtype='object')

# %% [markdown]
# ### Connecting London tube lines and station points with restaurant data so that layers can be visualized

# %% [markdown]
# #### Creating and adding a feature group made of tube lines

# %%
tube_linesgdf.head()
# Out:
#                                                Name Description  \
# 0           Bakerloo - Baker Street to Regents Park
# 1            Bakerloo - Charing Cross to Embankment
# 2  Bakerloo - Edgware Road (Bakerloo) to Marylebone
# 3                 Bakerloo - Embankment to Waterloo
# 4        Bakerloo - Harlesden to Willesden Junction
#
#                                             geometry
# 0  LINESTRING Z (-0.15690 51.52313 1.00000, -0.14...
# 1  LINESTRING Z (-0.12480 51.50836 1.00000, -0.12...
# 2  LINESTRING Z (-0.17054 51.52065 1.00000, -0.16...
# 3  LINESTRING Z (-0.12237 51.50731 1.00000, -0.11...
# 4  LINESTRING Z (-0.25750 51.53626 1.00000, -0.24...

# %% [markdown]
# for idx, pt in enumerate([list(tube_linesgdf.geometry[index_no].coords) for index_no in tube_linesgdf.index]):
#     print(tube_linesgdf.loc[idx]['Name'])

# %% [markdown]
# fg1 = folium.FeatureGroup(name='Tube', overlay=False, control=True)
# for idx, pt in enumerate([list(tube_linesgdf.geometry[index_no].coords) for index_no in tube_linesgdf.index]):
#     location = [pt[0][:2][::-1], pt[1][:2][::-1]] #obtaining only long, lat
#     fg1.add_child(folium.PolyLine(location, color='red', tooltip=tube_linesgdf.loc[idx]['Name']))
#     fg1.add_to(my_map)
#
# #my_map.add_child(fg1)
# # themap.save('map.html')
#
# # base_map = folium.FeatureGroup(name='Basemap', overlay=True, control=False)
# # folium.TileLayer(tiles='OpenStreetMap').add_to(base_map)
#
#
# #folium.LayerControl(collapsed=False).add_to(my_map)
# my_map.add_child(folium.LayerControl(collapsed=False))
# my_map

# %% [markdown]
# #### Creating and adding a feature group made of tube stations

# %%
tube_stnsgdf.head()
# Out:
#               Name                                        Description  \
# 0       Abbey Road  <div>Zone 3</div> <div>E15 3NB</div> <div>Lati...
# 1       Abbey Wood  <div>Zone 4</div> <div>SE2 9RH</div> <div>Lati...
# 2    Acton Central  <div>Zone 2</div> <div>W3 6BH</div> <div>Latit...
# 3  Acton Main Line  <div>Zone 3</div> <div>W3 9EH</div> <div>Latit...
# 4       Acton Town  <div>Zone 3</div> <div>W3 8HN</div> <div>Latit...
#
#                               geometry
# 0   POINT Z (0.00372 51.53195 0.00000)
# 1   POINT Z (0.12027 51.49078 0.00000)
# 2  POINT Z (-0.26343 51.50876 0.00000)
# 3  POINT Z (-0.26769 51.51689 0.00000)
# 4  POINT Z (-0.28030 51.50307 0.00000)

# %%
tstns_in_roi = gpd.overlay(tube_stnsgdf, 
                          buf4000_gdf.to_crs('epsg:4326'), 
                          how="intersection")
tstns_in_roi.plot(color='red')
plt.title('Tube stations in the area of interest')
# Out:
# Text(0.5, 1.0, 'Tube stations in the area of interest')

# %%
print(f'There are {len(tstns_in_roi)} tube stations in the area of interest i.e yellow buffer zone')
# Out:
# There are 74 tube stations in the area of interest i.e yellow buffer zone

# %% [markdown]
# [c for c in tstns_in_poi.geometry[0].coords][0][:2][::-1]

# %% [markdown]
# folium.Marker?

# %%
tlines_in_roi = gpd.overlay(tube_linesgdf, 
                          buf4000_gdf.to_crs('epsg:4326'), 
                          how="intersection")
tlines_in_roi.plot(color='red')
plt.title('Tube lines in the region of interest')
# Out:
# Text(0.5, 1.0, 'Tube lines in the region of interest')

# %%
tstns_in_roi.head()
# Out:
#            Name                                        Description  \
# 0       Aldgate  <div>Zone 1</div> <div>EC3N 1AH</div> <div>Lat...
# 1  Aldgate East  <div>Zone 1</div> <div>E1 7PT</div> <div>Latit...
# 2         Angel  <div>Zone 1</div> <div>N1 8XB</div> <div>Latit...
# 3          Bank  <div>Zone 1</div> <div>EC3V 3LA</div> <div>Lat...
# 4      Barbican  <div>Zone 1</div> <div>EC1A 4JA</div> <div>Lat...
#
#                               geometry
# 0  POINT Z (-0.07563 51.51434 0.00000)
# 1  POINT Z (-0.07300 51.51508 0.00000)
# 2  POINT Z (-0.10558 51.53297 0.00000)
# 3  POINT Z (-0.08900 51.51335 0.00000)
# 4  POINT Z (-0.09772 51.52022 0.00000)

# %%
for idx, tstn in enumerate([list(tstns_in_roi.geometry[index_no].coords) for index_no in tstns_in_roi.index]):
    location = list(tstn[0][:2][::-1]) #obtaining only long, lat
    
    # circle marker  'code adapted from https://stackoverflow.com/questions/60131314/folium-draw-star-marker'
    icon_circle = BeautifyIcon(
                  icon_shape='circle-dot', 
                  border_color='red', 
                  border_width=4.5,)
    folium.Marker(location, icon=icon_circle, tooltip=tstns_in_roi.loc[idx]['Name']).add_to(my_map)
    
    
    
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b2c3bf051945c89fe26e696e11f7b9e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b2c3bf051945c89fe26e696e11f7b9e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b2c3bf051945c89fe26e696e11f7b9e9 = L.map(
#                 &quot;map_b2c3bf051945c89fe26e696e11f7b9e9&quot;,
#                 {
#                     center: [51.5074, 0.1272],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d0b7c29d900ec3f413b5e5844510e307 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b2c3bf051945c89fe26e696e11f7b9e9);
#
#
#             var marker_00cebd5808b31a7c4af65da3053e28b1 = L.marker(
#                 [51.513632, -0.09599099999999999],
#                 {}
#             ).addTo(map_b2c3bf051945c89fe26e696e11f7b9e9);
#
#
#         var popup_5608d8ce3a4c7f7ce2133f0170ae14a3 = L.popup({&quot;maxWidth&quot;: 250, &quot;minWidth&quot;: 250});
#
#
#             var i_frame_0a6e979bf31c4ba44eb04f93e52823b0 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBOYW1lOiBHcmFidGhhaSBCYW5na29rIENhZmUgPGJyPlJhdGluZ1ZhbHVlOiA0IDxicj5Qb3N0Q29kZTogRUM0TSA5QUc=&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_5608d8ce3a4c7f7ce2133f0170ae14a3.setContent(i_frame_0a6e979bf31c4ba44eb04f93e52823b0);
#
#
#         marker_00cebd5808b31a7c4af65da3053e28b1.bindPopup(popup_5608d8ce3a4c7f7ce2133f0170ae14a3)
#         ;
#
#
#
#
#             var marker_0f3061dce2b55534a3e7d4b1c9da24a8 = L.marker(
#                 [51.484206, -0.176735],
#                 {}
#             ).addTo(map_b2c3bf051945c89fe26e696e11f7b9e9);
#
#
#         var popup_92623078bd7150dbc7c7f9550f6eee17 = L.popup({&quot;maxWidth&quot;: 250, &quot;minWidth&quot;: 250});
#
#
#             var i_frame_0e25f04b03447bdcd2f459db5fb583a6 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBOYW1lOiBCdXNhYmEgRWF0aGFpIDxicj5SYXRpbmdWYWx1ZTogNSA8YnI+UG9zdENvZGU6IFNXMyA1VVo=&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_92623078bd7150dbc7c7f9550f6eee17.setContent(i_frame_0e25f04b03447bdcd2f459db5fb583a6);
#
#
#         marker_0f3061dce2b55534a3e7d4b1c9da24a8.bindPopup(popup_92623078bd7150dbc7c7f9550f6eee17)
#         ;
#
#
#
#
#             var marker_ce734e580b2314c234a4f993473c3245 = L.marker(
#                 [51.513151, -0.137651],
#                 {}
#             ).addTo(map_b2c3bf051945c89fe26e696e11f7b9e9);
#
#
#         var popup_39b3a90ac3992eae90be2263de9a3610 = L.popup({&quot;maxWidth&quot;: 250, &quot;minWidth&quot;: 250});
#
#
#             var i_frame_ce4f1d36af1e7d3f402cddd81d07c1d3 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBOYW1lOiBCdXNhYmEgRWF0aGFpIDxicj5SYXRpbmdWYWx1ZTogMyA8YnI+UG9zdENvZGU6IFcxRiAwQVM=&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_39b3a90ac3992eae90be2263de9a3610.setContent(i_frame_ce4f1d36af1e7d3f402cddd81d07c1d3);
#
#
#         marker_ce734e580b2314c234a4f993473c3245.bindPopup(popup_39b3a90ac3992eae90be2263de9a3610)
#         ;
#
#
#
#
#             var marker_52bedcf39fe621e834f39626fe5f0656 = L.marker(
#                 [51.51307, -0.12361300000000001],
#                 {}
#             ).addTo(map_b2c3bf051945c89fe26e696e11f7b9e9);
#
#
#         var popup_401a31111f7a6e0ec851b23083dca61a = L.popup({&quot;maxWidth&quot;: 250, &quot;minWidth&quot;: 250});
#
#
#             var i_frame_f8990da05650e37a532cf5ee37cf291d = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relati

# %%
for idx, pt in enumerate([list(tlines_in_roi.geometry[index_no].coords) for index_no in tlines_in_roi.index]):
    location = [pt[0][:2][::-1], pt[1][:2][::-1]] #obtaining only long, lat
    folium.PolyLine(location, color='red', tooltip=tlines_in_roi.loc[idx]['Name']).add_to(my_map)

my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b2c3bf051945c89fe26e696e11f7b9e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b2c3bf051945c89fe26e696e11f7b9e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b2c3bf051945c89fe26e696e11f7b9e9 = L.map(
#                 &quot;map_b2c3bf051945c89fe26e696e11f7b9e9&quot;,
#                 {
#                     center: [51.5074, 0.1272],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d0b7c29d900ec3f413b5e5844510e307 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b2c3bf051945c89fe26e696e11f7b9e9);
#
#
#             var marker_00cebd5808b31a7c4af65da3053e28b1 = L.marker(
#                 [51.513632, -0.09599099999999999],
#                 {}
#             ).addTo(map_b2c3bf051945c89fe26e696e11f7b9e9);
#
#
#         var popup_5608d8ce3a4c7f7ce2133f0170ae14a3 = L.popup({&quot;maxWidth&quot;: 250, &quot;minWidth&quot;: 250});
#
#
#             var i_frame_0a6e979bf31c4ba44eb04f93e52823b0 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBOYW1lOiBHcmFidGhhaSBCYW5na29rIENhZmUgPGJyPlJhdGluZ1ZhbHVlOiA0IDxicj5Qb3N0Q29kZTogRUM0TSA5QUc=&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_5608d8ce3a4c7f7ce2133f0170ae14a3.setContent(i_frame_0a6e979bf31c4ba44eb04f93e52823b0);
#
#
#         marker_00cebd5808b31a7c4af65da3053e28b1.bindPopup(popup_5608d8ce3a4c7f7ce2133f0170ae14a3)
#         ;
#
#
#
#
#             var marker_0f3061dce2b55534a3e7d4b1c9da24a8 = L.marker(
#                 [51.484206, -0.176735],
#                 {}
#             ).addTo(map_b2c3bf051945c89fe26e696e11f7b9e9);
#
#
#         var popup_92623078bd7150dbc7c7f9550f6eee17 = L.popup({&quot;maxWidth&quot;: 250, &quot;minWidth&quot;: 250});
#
#
#             var i_frame_0e25f04b03447bdcd2f459db5fb583a6 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBOYW1lOiBCdXNhYmEgRWF0aGFpIDxicj5SYXRpbmdWYWx1ZTogNSA8YnI+UG9zdENvZGU6IFNXMyA1VVo=&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_92623078bd7150dbc7c7f9550f6eee17.setContent(i_frame_0e25f04b03447bdcd2f459db5fb583a6);
#
#
#         marker_0f3061dce2b55534a3e7d4b1c9da24a8.bindPopup(popup_92623078bd7150dbc7c7f9550f6eee17)
#         ;
#
#
#
#
#             var marker_ce734e580b2314c234a4f993473c3245 = L.marker(
#                 [51.513151, -0.137651],
#                 {}
#             ).addTo(map_b2c3bf051945c89fe26e696e11f7b9e9);
#
#
#         var popup_39b3a90ac3992eae90be2263de9a3610 = L.popup({&quot;maxWidth&quot;: 250, &quot;minWidth&quot;: 250});
#
#
#             var i_frame_ce4f1d36af1e7d3f402cddd81d07c1d3 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBOYW1lOiBCdXNhYmEgRWF0aGFpIDxicj5SYXRpbmdWYWx1ZTogMyA8YnI+UG9zdENvZGU6IFcxRiAwQVM=&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_39b3a90ac3992eae90be2263de9a3610.setContent(i_frame_ce4f1d36af1e7d3f402cddd81d07c1d3);
#
#
#         marker_ce734e580b2314c234a4f993473c3245.bindPopup(popup_39b3a90ac3992eae90be2263de9a3610)
#         ;
#
#
#
#
#             var marker_52bedcf39fe621e834f39626fe5f0656 = L.marker(
#                 [51.51307, -0.12361300000000001],
#                 {}
#             ).addTo(map_b2c3bf051945c89fe26e696e11f7b9e9);
#
#
#         var popup_401a31111f7a6e0ec851b23083dca61a = L.popup({&quot;maxWidth&quot;: 250, &quot;minWidth&quot;: 250});
#
#
#             var i_frame_f8990da05650e37a532cf5ee37cf291d = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relati

# %% [markdown]
# ------------------------------------------
